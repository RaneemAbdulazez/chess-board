# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Out:
# red is underattack

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-06fbba5ddd75> in <module>
#       6     print("all tests passed")
#       7
# ----> 8 chessBoard  = ChessBoard()
#       9 test_chess()
#      10 chessBoard.render([4,5],[2,5])
#
# NameError: name 'ChessBoard' is not defined
